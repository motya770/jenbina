# %%
# %pip install --upgrade setuptools
# %pip install ollama==0.3.3
# %pip install langchain-ollama==0.2.0
# %pip install langchain==0.3.1
# %pip install streamlit==1.38.0
# %pip install langchain-nomic==0.1.3
# Out:
# Requirement already satisfied: setuptools in /opt/homebrew/lib/python3.10/site-packages (75.1.0)
#
# [notice] A new release of pip available: 22.3 -> 24.2
# [notice] To update, run: /opt/homebrew/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ollama==0.3.3 in /opt/homebrew/lib/python3.10/site-packages (0.3.3)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /opt/homebrew/lib/python3.10/site-packages (from ollama==0.3.3) (0.27.2)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.10/site-packages (from httpx<0.28.0,>=0.27.0->ollama==0.3.3) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.10/site-packages (from httpx<0.28.0,>=0.27.0->ollama==0.3.3) (1.0.5)
# Requirement already satisfied: anyio in /opt/homebrew/lib/python3.10/site-packages (from httpx<0.28.0,>=0.27.0->ollama==0.3.3) (4.6.0)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.10/site-packages (from httpx<0.28.0,>=0.27.0->ollama==0.3.3) (2022.6.15)
# Requirement already satisfied: idna in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from httpx<0.28.0,>=0.27.0->ollama==0.3.3) (2.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/lib/python3.10/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama==0.3.3) (0.14.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/homebrew/lib/python3.10/site-packages (from anyio->httpx<0.28.0,>=0.27.0->ollama==0.3.3) (1.2.2)
# Requirement already satisfied: typing-extensions>=4.1 in /opt/homebrew/lib/python3.10/site-packages (from anyio->httpx<0.28.0,>=0.27.0->ollama==0.3.3) (4.12.2)
#
# [notice] A new release of pip available: 22.3 -> 24.2
# [notice] To update, run: /opt/homebrew/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain-ollama==0.2.0 in /opt/homebrew/lib/python3.10/site-packages (0.2.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.0 in /opt/homebrew/lib/python3.10/site-packages (from langchain-ollama==0.2.0) (0.3.6)
# Requirement already satisfied: ollama<1,>=0.3.0 in /opt/homebrew/lib/python3.10/site-packages (from langchain-ollama==0.2.0) (0.3.3)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama==0.2.0) (23.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/homebrew/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama==0.2.0) (8.5.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /opt/homebrew/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama==0.2.0) (0.1.129)
# Requirement already satisfied: PyYAML>=5.3 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama==0.2.0) (6.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /opt/homebrew/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama==0.2.0) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/homebrew/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama==0.2.0) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/homebrew/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama==0.2.0) (1.33)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /opt/homebrew/lib/python3.10/site-packages (from ollama<1,>=0.3.0->langchain-ollama==0.2.0) (0.27.2)
# Requirement already satisfied: anyio in /opt/homebrew/lib/python3.10/site-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama==0.2.0) (4.6.0)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.10/site-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama==0.2.0) (2022.6.15)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.10/site-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama==0.2.0) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.10/site-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama==0.2.0) (1.0.5)
# Requirement already satisfied: idna in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama==0.2.0) (2.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/lib/python3.10/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama==0.2.0) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain-ollama==0.2.0) (3.0.0)
# Requirement already satisfied: requests<3,>=2 in /opt/homebrew/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.0->langchain-ollama==0.2.0) (2.32.3)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/homebrew/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.0->langchain-ollama==0.2.0) (3.10.7)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/homebrew/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.0->langchain-ollama==0.2.0) (2.23.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.0->langchain-ollama==0.2.0) (0.7.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.0->langchain-ollama==0.2.0) (1.26.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.0->langchain-ollama==0.2.0) (2.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/homebrew/lib/python3.10/site-packages (from anyio->httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama==0.2.0) (1.2.2)
#
# [notice] A new release of pip available: 22.3 -> 24.2
# [notice] To update, run: /opt/homebrew/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain==0.3.1 in /opt/homebrew/lib/python3.10/site-packages (0.3.1)
# Requirement already satisfied: numpy<2,>=1 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from langchain==0.3.1) (1.23.5)
# Requirement already satisfied: PyYAML>=5.3 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from langchain==0.3.1) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/homebrew/lib/python3.10/site-packages (from langchain==0.3.1) (1.4.40)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.6 in /opt/homebrew/lib/python3.10/site-packages (from langchain==0.3.1) (0.3.6)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /opt/homebrew/lib/python3.10/site-packages (from langchain==0.3.1) (0.3.0)
# Requirement already satisfied: requests<3,>=2 in /opt/homebrew/lib/python3.10/site-packages (from langchain==0.3.1) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/homebrew/lib/python3.10/site-packages (from langchain==0.3.1) (8.5.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/homebrew/lib/python3.10/site-packages (from langchain==0.3.1) (0.1.129)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/homebrew/lib/python3.10/site-packages (from langchain==0.3.1) (2.9.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/homebrew/lib/python3.10/site-packages (from langchain==0.3.1) (3.10.8)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/homebrew/lib/python3.10/site-packages (from langchain==0.3.1) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.1) (1.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.1) (2.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.1) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.1) (1.13.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.1) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.1) (6.1.0)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain==0.3.1) (23.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/homebrew/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain==0.3.1) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/homebrew/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain==0.3.1) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/homebrew/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.1) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/homebrew/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.1) (3.10.7)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/homebrew/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.1) (2.23.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.1) (0.7.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from requests<3,>=2->langchain==0.3.1) (2.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests<3,>=2->langchain==0.3.1) (2.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from requests<3,>=2->langchain==0.3.1) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.10/site-packages (from requests<3,>=2->langchain==0.3.1) (2022.6.15)
# Requirement already satisfied: anyio in /opt/homebrew/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.1) (4.6.0)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.1) (1.0.5)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.1) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.1) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.6->langchain==0.3.1) (3.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/homebrew/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.1) (1.2.2)
#
# [notice] A new release of pip available: 22.3 -> 24.2
# [notice] To update, run: /opt/homebrew/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: streamlit==1.38.0 in /opt/homebrew/lib/python3.10/site-packages (1.38.0)
# Requirement already satisfied: click<9,>=7.0 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from streamlit==1.38.0) (8.1.3)
# Requirement already satisfied: protobuf<6,>=3.20 in /opt/homebrew/lib/python3.10/site-packages (from streamlit==1.38.0) (4.21.5)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from streamlit==1.38.0) (5.0.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /opt/homebrew/lib/python3.10/site-packages (from streamlit==1.38.0) (0.9.1)
# Requirement already satisfied: pyarrow>=7.0 in /opt/homebrew/lib/python3.10/site-packages (from streamlit==1.38.0) (9.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /opt/homebrew/lib/python3.10/site-packages (from streamlit==1.38.0) (3.1.27)
# Requirement already satisfied: altair<6,>=4.0 in /opt/homebrew/lib/python3.10/site-packages (from streamlit==1.38.0) (5.4.1)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from streamlit==1.38.0) (12.6.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from streamlit==1.38.0) (1.5.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from streamlit==1.38.0) (9.3.0)
# Requirement already satisfied: requests<3,>=2.27 in /opt/homebrew/lib/python3.10/site-packages (from streamlit==1.38.0) (2.32.3)
# Requirement already satisfied: blinker<2,>=1.0.0 in /opt/homebrew/lib/python3.10/site-packages (from streamlit==1.38.0) (1.8.2)
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/homebrew/lib/python3.10/site-packages (from streamlit==1.38.0) (6.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /opt/homebrew/lib/python3.10/site-packages (from streamlit==1.38.0) (0.10.2)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /opt/homebrew/lib/python3.10/site-packages (from streamlit==1.38.0) (8.5.0)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /opt/homebrew/lib/python3.10/site-packages (from streamlit==1.38.0) (4.12.2)
# Requirement already satisfied: numpy<3,>=1.20 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from streamlit==1.38.0) (1.23.5)
# Requirement already satisfied: packaging<25,>=20 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from streamlit==1.38.0) (23.2)
# Requirement already satisfied: narwhals>=1.5.2 in /opt/homebrew/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit==1.38.0) (1.8.4)
# Requirement already satisfied: jsonschema>=3.0 in /opt/homebrew/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit==1.38.0) (4.10.0)
# Requirement already satisfied: jinja2 in /opt/homebrew/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit==1.38.0) (3.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/homebrew/lib/python3.10/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.38.0) (4.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from pandas<3,>=1.3.0->streamlit==1.38.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from pandas<3,>=1.3.0->streamlit==1.38.0) (2022.6)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from requests<3,>=2.27->streamlit==1.38.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit==1.38.0) (2022.6.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit==1.38.0) (2.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from requests<3,>=2.27->streamlit==1.38.0) (1.26.12)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from rich<14,>=10.14.0->streamlit==1.38.0) (2.13.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from rich<14,>=10.14.0->streamlit==1.38.0) (0.9.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/homebrew/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.38.0) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.10/site-packages (from jinja2->altair<6,>=4.0->streamlit==1.38.0) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/homebrew/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.38.0) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/homebrew/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.38.0) (0.18.1)
# Requirement already satisfied: six>=1.5 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.8.1->pandas<3,>=1.3.0->streamlit==1.38.0) (1.16.0)
#
# [notice] A new release of pip available: 22.3 -> 24.2
# [notice] To update, run: /opt/homebrew/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain-nomic==0.1.3
#   Using cached langchain_nomic-0.1.3-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.2.40 in /opt/homebrew/lib/python3.10/site-packages (from langchain-nomic==0.1.3) (0.3.6)
# Collecting pillow<11.0.0,>=10.3.0
#   Using cached pillow-10.4.0-cp310-cp310-macosx_11_0_arm64.whl (3.4 MB)
# Collecting nomic<4.0.0,>=3.1.2
#   Using cached nomic-3.1.2.tar.gz (45 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [52 lines of output]
#       Error in sitecustomize; set PYTHONVERBOSE for traceback:
#       AssertionError:
#       running egg_info
#       writing nomic.egg-info/PKG-INFO
#       writing dependency_links to nomic.egg-info/dependency_links.txt
#       writing entry points to nomic.egg-info/entry_points.txt
#       writing requirements to nomic.egg-info/requires.txt
#       writing top-level names to nomic.egg-info/top_level.txt
#       reading manifest file 'nomic.egg-info/SOURCES.txt'
#       Traceback (most recent call last):
#         File "/Users/wizard/Library/Python/3.10/lib/python/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 351, in <module>
#           main()
#         File "/Users/wizard/Library/Python/3.10/lib/python/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 333, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "/Users/wizard/Library/Python/3.10/lib/python/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "/opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/build_meta.py", line 332, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#         File "/opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/build_meta.py", line 302, in _get_build_requires
#           self.run_setup()
#         File "/opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/build_meta.py", line 503, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "/opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/build_meta.py", line 318, in run_setup
#           exec(code, locals())
#         File "<string>", line 9, in <module>
#         File "/opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/__init__.py", line 117, in setup
#           return distutils.core.setup(**attrs)
#         File "/opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 183, in setup
#           return run_commands(dist)
#         File "/opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 199, in run_commands
#           dist.run_commands()
#         File "/opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 954, in run_commands
#           self.run_command(cmd)
#         File "/opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/dist.py", line 950, in run_command
#           super().run_command(command)
#         File "/opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 973, in run_command
#           cmd_obj.run()
#         File "/opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 311, in run
#           self.find_sources()
#         File "/opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 319, in find_sources
#           mm.run()
#         File "/opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/command/egg_info.py", line 545, in run
#           self.prune_file_list()
#         File "/opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/command/sdist.py", line 161, in prune_file_list
#           super().prune_file_list()
#         File "/opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/_distutils/command/sdist.py", line 380, in prune_file_list
#           base_dir = self.distribution.get_fullname()
#         File "/opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/_core_metadata.py", line 267, in get_fullname
#           return _distribution_fullname(self.get_name(), self.get_version())
#         File "/opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/_core_metadata.py", line 285, in _distribution_fullname
#           canonicalize_version(version, strip_trailing_zero=False),
#       TypeError: canonicalize_version() got an unexpected keyword argument 'strip_trailing_zero'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip available: 22.3 -> 24.2
# [notice] To update, run: /opt/homebrew/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langchain langchain_community tiktoken langchain-nomic "nomic[local]" langchain-ollama scikit-learn langgraph tavily-python bs4

# %%
### LLM
from langchain_ollama import ChatOllama
local_llm = 'llama3.2:3b-instruct-fp16'
llm = ChatOllama(model=local_llm, temperature=0)
llm_json_mode = ChatOllama(model=local_llm, temperature=0, format='json')

# %%
# Out:
# Collecting langchain-ollama
#   Downloading langchain_ollama-0.2.0-py3-none-any.whl (14 kB)
# Collecting ollama<1,>=0.3.0
#   Downloading ollama-0.3.3-py3-none-any.whl (10 kB)
# Collecting langchain-core<0.4.0,>=0.3.0
#   Downloading langchain_core-0.3.6-py3-none-any.whl (399 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.9/399.9 kB 2.9 MB/s eta 0:00:00a 0:00:01
# Collecting langsmith<0.2.0,>=0.1.125
#   Downloading langsmith-0.1.129-py3-none-any.whl (292 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.2/292.2 kB 15.3 MB/s eta 0:00:00
# Collecting pydantic<3.0.0,>=2.5.2
#   Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.9/434.9 kB 15.8 MB/s eta 0:00:00
# Collecting jsonpatch<2.0,>=1.33
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama) (23.2)
# Requirement already satisfied: PyYAML>=5.3 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-ollama) (6.0)
# Collecting typing-extensions>=4.7
#   Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0
#   Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Collecting httpx<0.28.0,>=0.27.0
#   Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.10/site-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama) (2022.6.15)
# Collecting anyio
#   Downloading anyio-4.6.0-py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.6/89.6 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: idna in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain-ollama) (2.10)
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Collecting sniffio
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting h11<0.15,>=0.13
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: requests<3,>=2 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.0->langchain-ollama) (2.25.1)
# Collecting orjson<4.0.0,>=3.9.14
#   Downloading orjson-3.10.7-cp310-cp310-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.3/251.3 kB 18.0 MB/s eta 0:00:00
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.23.4
#   Downloading pydantic_core-2.23.4-cp310-cp310-macosx_11_0_arm64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 21.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/wizard/Library/Python/3.10/lib/python/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.0->langchain-ollama) (1.26.12)
# Collecting chardet<5,>=3.0.2
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting exceptiongroup>=1.0.2
#   Using cached exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Installing collected packages: typing-extensions, tenacity, sniffio, orjson, jsonpointer, h11, exceptiongroup, chardet, annotated-types, pydantic-core, jsonpatch, httpcore, anyio, pydantic, httpx, ollama, langsmith, langchain-core, langchain-ollama
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.4.0
#     Uninstalling typing_extensions-4.4.0:
#       Successfully uninstalled typing_extensions-4.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlflow 1.28.0 requires packaging<22, but you have packaging 23.2 which is incompatible.
# Successfully installed annotated-types-0.7.0 anyio-4.6.0 chardet-4.0.0 exceptiongroup-1.2.2 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 jsonpatch-1.33 jsonpointer-3.0.0 langchain-core-0.3.6 langchain-ollama-0.2.0 langsmith-0.1.129 ollama-0.3.3 orjson-3.10.7 pydantic-2.9.2 pydantic-core-2.23.4 sniffio-1.3.1 tenacity-8.5.0 typing-extensions-4.12.2
#
# [notice] A new release of pip available: 22.3 -> 24.2
# [notice] To update, run: /opt/homebrew/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
_set_env("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = "local-llama32-rag"
# Out:
# LANGCHAIN_API_KEY: ········

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import SKLearnVectorStore
from langchain_nomic.embeddings import NomicEmbeddings

urls = [
    "https://lilianweng.github.io/posts/2023-06-23-agent/",
    "https://lilianweng.github.io/posts/2023-03-15-prompt-engineering/",
    "https://lilianweng.github.io/posts/2023-10-25-adv-attack-llm/",
]

# Load documents
docs = [WebBaseLoader(url).load() for url in urls]
docs_list = [item for sublist in docs for item in sublist]

# Split documents
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=1000, chunk_overlap=200
)
doc_splits = text_splitter.split_documents(docs_list)

# Add to vectorDB
vectorstore = SKLearnVectorStore.from_documents(
    documents=doc_splits,
    embedding=NomicEmbeddings(model="nomic-embed-text-v1.5", inference_mode="local"),
)

# Create retriever
retriever = vectorstore.as_retriever(k=3)
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 274M/274M [00:09<00:00, 29.6MiB/s]
# Verifying: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 274M/274M [00:00<00:00, 470MiB/s]

# %%
### Router
import json
from langchain_core.messages import HumanMessage, SystemMessage

# Prompt 
router_instructions = """You are an expert at routing a user question to a vectorstore or web search.

The vectorstore contains documents related to agents, prompt engineering, and adversarial attacks.
                                    
Use the vectorstore for questions on these topics. For all else, and especially for current events, use web-search.

Return JSON with single key, datasource, that is 'websearch' or 'vectorstore' depending on the question."""

# Test router
test_web_search = llm_json_mode.invoke([SystemMessage(content=router_instructions)] + [HumanMessage(content="Who is favored to win the NFC Championship game in the 2024 season?")])
test_web_search_2 = llm_json_mode.invoke([SystemMessage(content=router_instructions)] + [HumanMessage(content="What are the models released today for llama3.2?")])
test_vector_store = llm_json_mode.invoke([SystemMessage(content=router_instructions)] + [HumanMessage(content="What are the types of agent memory?")])
print(json.loads(test_web_search.content), json.loads(test_web_search_2.content), json.loads(test_vector_store.content))
# Out:
# {'datasource': 'websearch'} {'datasource': 'websearch'} {'datasource': 'vectorstore'}

# %%
### Retrieval Grader 

# Doc grader instructions 
doc_grader_instructions = """You are a grader assessing relevance of a retrieved document to a user question.

If the document contains keyword(s) or semantic meaning related to the question, grade it as relevant."""

# Grader prompt
doc_grader_prompt = """Here is the retrieved document: \n\n {document} \n\n Here is the user question: \n\n {question}. 

This carefully and objectively assess whether the document contains at least some information that is relevant to the question.

Return JSON with single key, binary_score, that is 'yes' or 'no' score to indicate whether the document contains at least some information that is relevant to the question."""

# Test
question = "What is Chain of thought prompting?"
docs = retriever.invoke(question)
doc_txt = docs[1].page_content
doc_grader_prompt_formatted = doc_grader_prompt.format(document=doc_txt, question=question)
result = llm_json_mode.invoke([SystemMessage(content=doc_grader_instructions)] + [HumanMessage(content=doc_grader_prompt_formatted)])
json.loads(result.content)
# Out:
# {'binary_score': 'yes'}

# %%
### Retrieval Grader 

# Doc grader instructions 
doc_grader_instructions = """You are a grader assessing relevance of a retrieved document to a user question.

If the document contains keyword(s) or semantic meaning related to the question, grade it as relevant."""

# Grader prompt
doc_grader_prompt = """Here is the retrieved document: \n\n {document} \n\n Here is the user question: \n\n {question}. 

This carefully and objectively assess whether the document contains at least some information that is relevant to the question.

Return JSON with single key, binary_score, that is 'yes' or 'no' score to indicate whether the document contains at least some information that is relevant to the question."""

# Test
question = "What is Chain of thought prompting?"
docs = retriever.invoke(question)
doc_txt = docs[1].page_content
doc_grader_prompt_formatted = doc_grader_prompt.format(document=doc_txt, question=question)
result = llm_json_mode.invoke([SystemMessage(content=doc_grader_instructions)] + [HumanMessage(content=doc_grader_prompt_formatted)])
json.loads(result.content)
# Out:
# {'binary_score': 'yes'}

# %%
### Generate

# Prompt
rag_prompt = """You are an assistant for question-answering tasks. 

Here is the context to use to answer the question:

{context} 

Think carefully about the above context. 

Now, review the user question:

{question}

Provide an answer to this questions using only the above context. 

Use three sentences maximum and keep the answer concise.

Answer:"""

# Post-processing
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# Test
docs = retriever.invoke(question)
docs_txt = format_docs(docs)
rag_prompt_formatted = rag_prompt.format(context=docs_txt, question=question)
generation = llm.invoke([HumanMessage(content=rag_prompt_formatted)])
print(generation.content)
# Out:
# Chain of Thought (CoT) prompting is a technique used in natural language processing to generate human-like responses by iteratively asking questions and refining the search space through external search queries, such as Wikipedia APIs. CoT prompting involves decomposing problems into multiple thought steps, generating multiple thoughts per step, and evaluating each state using a classifier or majority vote. The goal is to find an optimal instruction that leads to the desired output, which can be achieved by optimizing prompt parameters directly on the embedding space via gradient descent or searching over a pool of model-generated instruction candidates.

# %%
### Hallucination Grader 

# Hallucination grader instructions 
hallucination_grader_instructions = """

You are a teacher grading a quiz. 

You will be given FACTS and a STUDENT ANSWER. 

Here is the grade criteria to follow:

(1) Ensure the STUDENT ANSWER is grounded in the FACTS. 

(2) Ensure the STUDENT ANSWER does not contain "hallucinated" information outside the scope of the FACTS.

Score:

A score of yes means that the student's answer meets all of the criteria. This is the highest (best) score. 

A score of no means that the student's answer does not meet all of the criteria. This is the lowest possible score you can give.

Explain your reasoning in a step-by-step manner to ensure your reasoning and conclusion are correct. 

Avoid simply stating the correct answer at the outset."""

# Grader prompt
hallucination_grader_prompt = """FACTS: \n\n {documents} \n\n STUDENT ANSWER: {generation}. 

Return JSON with two two keys, binary_score is 'yes' or 'no' score to indicate whether the STUDENT ANSWER is grounded in the FACTS. And a key, explanation, that contains an explanation of the score."""

# Test using documents and generation from above 
hallucination_grader_prompt_formatted = hallucination_grader_prompt.format(documents=docs_txt, generation=generation.content)
result = llm_json_mode.invoke([SystemMessage(content=hallucination_grader_instructions)] + [HumanMessage(content=hallucination_grader_prompt_formatted)])
json.loads(result.content)
# Out:
# {'binary_score': 'yes',
#  'explanation': 'The student answer provides a clear and accurate description of Chain of Thought (CoT) prompting, its components, and its goals. It also mentions various techniques used in CoT prompting, such as external search queries, prompt tuning, and automatic prompt engineering. The answer demonstrates an understanding of the concept and its applications in natural language processing.'}

# %%
### Search
from langchain_community.tools.tavily_search import TavilySearchResults
web_search_tool = TavilySearchResults(k=3)
